# %%
pip install wpparser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wpparser: filename=wpparser-1.1.2-py3-none-any.whl size=5405 sha256=8e7684c55897980508b5445b73727fbdc21d794ae9b69ad82400f1a7835f7ee8
#   Stored in directory: /root/.cache/pip/wheels/8e/c0/30/0e7f4daf3517ef36b0bcdcf76974066d0683dc789c5b864684
# ...
#   Created wheel for phpserialize: filename=phpserialize-1.3-py3-none-any.whl size=9469 sha256=88f50f2d9df370c01a5ac673919f763e74428bfc836fc6c70e643df625d53287
#   Stored in directory: /root/.cache/pip/wheels/80/1d/72/32b477bd722390ad47ac234ac8e5d0754bf83929c2fa78813f
# Successfully built wpparser phpserialize
# ...

# %%
import wpparser

# %%
data=wpparser.parse("ihub.WordPress.2023-07-06.xml")

# %%
data
# Out:
# {'blog': {'title': 'iHub',
#   'tagline': 'iHub and HCI Foundation',
#   'language': 'en-US',
#   'site_url': 'https://www.ihubiitmandi.in',
#   'blog_url': 'https://www.ihubiitmandi.in'},
#  'authors': [{'login': 'admin',
#    'email': 'anish@socialdna.in',
#    'display_name': 'iHub',
#    'first_name': None,
#    'last_name': None},
#   {'login': 'Arnav Bhavsar',
#    'email': 'arnav@iitmandi.ac.in',
#    'display_name': 'Arnav Bhavsar',
#    'first_name': 'Arnav',
#    'last_name': 'Bhavsar'},
#   {'login': 'Satyajit Thakor',
#    'email': 'satyajit@iitmandi.ac.in',
#    'display_name': 'Satyajit Thakor',
#    'first_name': 'Satyajit',
#    'last_name': 'Thakor'},
#   {'login': 'Aditya Nigam',
#    'email': 'srikanth@socialdna.in',
#    'display_name': 'Aditya Nigam',
#    'first_name': 'Aditya',
#    'last_name': 'Nigam'},
#   {'login': 'anishkholay',
#    'email': 'anishkholay@gmail.com',
#    'display_name': 'anishkholay',
#    'first_name': None,
#    'last_name': None},
# ...

# %%
file=open("file1.txt","wt")

# %%
for i,key in enumerate(data['posts']):

    file=open("file"+str(i)+" .txt","wt")
    file.write(str(key))
    file.close()
